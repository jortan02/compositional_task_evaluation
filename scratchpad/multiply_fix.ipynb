# %%
import pandas as pd

# %%
for i in range(10):
    df1 = pd.read_csv("data/multiplication/instruction_type-1/prompt_type-1/multiply.csv")
    df2 = pd.read_csv(f"results/multiplication/instruction_type-1/prompt_type-1/multiply/google/flan-t5-large/experiment-{i + 1}.csv")
    data1 = pd.concat([df1,df2["prediction"]], axis = 1)
    data1.to_csv(f"results/multiplication/instruction_type-1/prompt_type-1/multiply/google/flan-t5-large/experiment-{i + 1}.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /uufs/chpc.utah.edu/common/home/u1283221/compositional_task_evaluation/fix.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bnotchpeak.chpc.utah.edu/uufs/chpc.utah.edu/common/home/u1283221/compositional_task_evaluation/fix.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for i in range(10):
#       <a href='vscode-notebook-cell://ssh-remote%2Bnotchpeak.chpc.utah.edu/uufs/chpc.utah.edu/common/home/u1283221/compositional_task_evaluation/fix.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     df1 = pd.read_csv("data/multiplication/instruction_type-1/prompt_type-1/multiply.csv")
# ...

# %%
data1
# Out:
#                  instruction                     example         question  \
# 0      Multiply two numbers.                  6 * 6 = 36          0 * 0 =
# 1      Multiply two numbers.                  6 * 6 = 36          0 * 1 =
# 2      Multiply two numbers.                  6 * 6 = 36          0 * 2 =
# 3      Multiply two numbers.                  6 * 6 = 36          0 * 3 =
# 4      Multiply two numbers.                  6 * 6 = 36          0 * 4 =
# ...                      ...                         ...              ...
# 64995  Multiply two numbers.  30939 * 39753 = 1229918067  82234 * 66020 =
# 64996  Multiply two numbers.  30939 * 39753 = 1229918067  92267 * 93525 =
# 64997  Multiply two numbers.  30939 * 39753 = 1229918067  94888 * 95553 =
# 64998  Multiply two numbers.  30939 * 39753 = 1229918067  93073 * 29876 =
# 64999  Multiply two numbers.  30939 * 39753 = 1229918067  21744 * 67806 =
#
#            answer prediction
# 0               0         12
# ...

# %%
df1
# Out:
#                  instruction                     example         question  \
# 0      Multiply two numbers.                  6 * 6 = 36          0 * 0 =
# 1      Multiply two numbers.                  6 * 6 = 36          0 * 1 =
# 2      Multiply two numbers.                  6 * 6 = 36          0 * 2 =
# 3      Multiply two numbers.                  6 * 6 = 36          0 * 3 =
# 4      Multiply two numbers.                  6 * 6 = 36          0 * 4 =
# ...                      ...                         ...              ...
# 64995  Multiply two numbers.  30939 * 39753 = 1229918067  82234 * 66020 =
# 64996  Multiply two numbers.  30939 * 39753 = 1229918067  92267 * 93525 =
# 64997  Multiply two numbers.  30939 * 39753 = 1229918067  94888 * 95553 =
# 64998  Multiply two numbers.  30939 * 39753 = 1229918067  93073 * 29876 =
# 64999  Multiply two numbers.  30939 * 39753 = 1229918067  21744 * 67806 =
#
#            answer
# 0               0
# 1               0
# 2               0
# ...

# %%
df2
# Out:
#                  instruction                     example         question  \
# 0      Multiply two numbers.                  6 * 6 = 36          0 * 0 =
# 1      Multiply two numbers.                  6 * 6 = 36          0 * 1 =
# 2      Multiply two numbers.                  6 * 6 = 36          0 * 2 =
# 3      Multiply two numbers.                  6 * 6 = 36          0 * 3 =
# 4      Multiply two numbers.                  6 * 6 = 36          0 * 4 =
# ...                      ...                         ...              ...
# 64995  Multiply two numbers.  30939 * 39753 = 1229918067  82234 * 66020 =
# 64996  Multiply two numbers.  30939 * 39753 = 1229918067  92267 * 93525 =
# 64997  Multiply two numbers.  30939 * 39753 = 1229918067  94888 * 95553 =
# 64998  Multiply two numbers.  30939 * 39753 = 1229918067  93073 * 29876 =
# 64999  Multiply two numbers.  30939 * 39753 = 1229918067  21744 * 67806 =
#
#            answer prediction
# 0         0 * 0 =         12
# ...

# %%
for i in range(10):
    df = pd.read_csv(f"../results/multiplication/instruction_type-1/prompt_type-1/multiply/google/flan-t5-small/experiment-{i + 1}.csv")
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df.to_csv(f"../results/multiplication/instruction_type-1/prompt_type-1/multiply/google/flan-t5-small/experiment-{i + 1}.csv", index=False)

# %%
df = pd.read_csv(f"../results/multiplication/instruction_type-1/prompt_type-1/multiply/google/flan-t5-large/experiment-{1}.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#                  instruction                     example         question  \
# 0      Multiply two numbers.                  6 * 6 = 36          0 * 0 =
# 1      Multiply two numbers.                  6 * 6 = 36          0 * 1 =
# 2      Multiply two numbers.                  6 * 6 = 36          0 * 2 =
# 3      Multiply two numbers.                  6 * 6 = 36          0 * 3 =
# 4      Multiply two numbers.                  6 * 6 = 36          0 * 4 =
# ...                      ...                         ...              ...
# 64995  Multiply two numbers.  30939 * 39753 = 1229918067  82234 * 66020 =
# 64996  Multiply two numbers.  30939 * 39753 = 1229918067  92267 * 93525 =
# 64997  Multiply two numbers.  30939 * 39753 = 1229918067  94888 * 95553 =
# 64998  Multiply two numbers.  30939 * 39753 = 1229918067  93073 * 29876 =
# 64999  Multiply two numbers.  30939 * 39753 = 1229918067  21744 * 67806 =
#
#            answer prediction
# 0               0          0
# ...
