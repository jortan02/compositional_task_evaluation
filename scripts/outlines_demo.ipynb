# %%
# !pip install -r ../requirements_freeze.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !python3 -m pip install -U "huggingface_hub[cli]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !huggingface-cli login
# Out:
# /bin/bash: huggingface-cli: command not found

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# accelerate                    0.27.2
# aiohttp                       3.9.3
# aiosignal                     1.3.1
# alabaster                     0.7.12
# annotated-types               0.6.0
# anyio                         3.5.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# asteval                       0.9.27.post2+g33148ad
# astroid                       2.11.1
# astropy                       5.2.1
# asttokens                     2.0.5
# async-timeout                 4.0.3
# atomicwrites                  1.4.0
# attrs                         23.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.10.0
# beniget                       0.4.1
# binaryornot                   0.4.4
# biopython                     1.79
# ...

# %%
import outlines
from datasets_helper import *

# %%
# !conda activate compositional

# %%
mkdir /scratch/general/vast/u1283221/huggingface_cache
# Out:
# mkdir: cannot create directory ‘/scratch/general/vast/u1283221/huggingface_cache’: File exists

# %%
# !export TRANSFORMERS_CACHE="/scratch/general/vast/u1283221/huggingface_cache"

# %%
get_full_prompt(get_llama_2_chat_prompt_format, "Concatenate the two word lists.", "Concatenate of testis, poplin, io and cakile, trip, bextra is what?", "testis, poplin, io, cakile, trip, bextra", "Concatenate of testis, poplin, io and cakile, trip, bextra is what?")
# Out:
# '[INST] Q: Concatenate the two word lists.\ntestis, poplin, io, cakile, trip, bextra [\\INST]\nA: Concatenate of testis, poplin, io and cakile, trip, bextra is what?\n\n[INST] Q: Concatenate the two word lists.\nConcatenate of testis, poplin, io and cakile, trip, bextra is what? [\\INST]\nA: '

# %%
model = outlines.models.transformers("meta-llama/Llama-2-7b-chat-hf")

prompt = get_full_prompt(get_llama_2_chat_prompt_format, "Concatenate the two word lists.", "Concatenate of testis, poplin, io and cakile, trip, bextra is what?", "testis, poplin, io, cakile, trip, bextra", "Concatenate of testis, poplin, io and cakile, trip, bextra is what?")

generator = outlines.generate.text(model)
unstructured = generator(prompt, max_tokens=30)
unstructured
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
