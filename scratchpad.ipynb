# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration

"""Define model"""
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base", device_map="auto")
"""Define tokenizer"""
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

device = 'cuda' if torch.cuda.is_available() else 'cpu'

texts = ["1+1", "2+2"]
encoding = tokenizer(texts, padding=True, truncation=True, return_tensors='pt').to(device)
with torch.no_grad():
    generated_ids = model.generate(**encoding)
generated_texts = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
print(generated_texts)

# %%
def foo():
    return 1, 2

a = foo()

# %%
a
# Out:
# (1, 2)

# %%
from datasets import load_dataset, Features, Value
dataset = load_dataset("csv", delimiter=',', data_files="./data/concatenation.csv", features=Features({"question": Value("string"), "answer": Value("string")}))["train"]
print(dataset["question"])
print(dataset["answer"])
# Out:
# ['Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 0 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 1 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 2 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 3 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 4 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 5 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 6 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 7 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 8 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 0 & 9 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 1 & 0 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 1 & 1 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 1 & 2 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 153\n###\n0 & 1 & 3 =', 'Concatenate the numbers.\n###\n1 & 5 & 3 = 1
# ...

# %%
dataset.to_csv("dummy.csv")
# Out:
# ...
# Creating CSV from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 29.92ba/s]
# 66906

# %%
import os
os.environ['TRANSFORMERS_CACHE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 os.environ['TRANSFORMERS_CACHE']
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: 'TRANSFORMERS_CACHE'

# %%
import pandas as pd

MULTIPLICATION_PATH = "results/multiplication"
CARRY_PATH = f"{MULTIPLICATION_PATH}/carry"

results_df = pd.read_csv(f"{CARRY_PATH}/flan-t5-base_carry.csv")
results_df.sample(1, random_state=0)["question"].item()
# Out:
# 'Carry the digit from the tens place.\n###\n15 // 10 = 1\n###\n26 // 10 ='
